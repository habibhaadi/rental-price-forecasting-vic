# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("test").getOrCreate()
print(spark.version)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/09/09 12:53:00 WARN Utils: Your hostname, PC, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/09/09 12:53:00 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/09/09 12:53:01 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 4.0.1

# %%
import pandas as pd

one_flat = pd.read_csv('data/one_bed_flat.csv', skiprows=1)

one_flat.rename(columns={'1 bedroom flat': 'region'}, inplace=True)
one_flat['region'] = one_flat['region'].fillna(method='ffill')

print(one_flat.head(10))
print(one_flat.columns)
print(one_flat.dtypes)
# Out:
#             region                             Unnamed: 1 Mar 2000 Unnamed: 3  \
# 0              NaN                                    NaN    Count     Median
# 1  Inner Melbourne  Albert Park-Middle Park-West St Kilda      352       $165
# 2  Inner Melbourne                               Armadale      210       $150
# 3  Inner Melbourne                          Carlton North       87       $150
# 4  Inner Melbourne                      Carlton-Parkville      303       $165
# 5  Inner Melbourne                        CBD-St Kilda Rd      755       $250
# 6  Inner Melbourne                 Collingwood-Abbotsford      130       $135
# 7  Inner Melbourne                              Docklands        -          -
# 8  Inner Melbourne                         East Melbourne      203       $180
# 9  Inner Melbourne                          East St Kilda      613       $140
#
#   Jun 2000 Unnamed: 5 Sep 2000 Unnamed: 7 Dec 2000 Unnamed: 9  ... Mar 2022  \
# ...
